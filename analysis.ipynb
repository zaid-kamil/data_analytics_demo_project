# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv("data/ASIANPAINT.csv",parse_dates=['Date'],index_col='Date')

# %%
df.columns.tolist()
# Out:
# ['Symbol',
#  'Series',
#  'Prev Close',
#  'Open',
#  'High',
#  'Low',
#  'Last',
#  'Close',
#  'VWAP',
#  'Volume',
#  'Turnover',
#  'Trades',
#  'Deliverable Volume',
#  '%Deliverble']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5097 entries, 2000-01-03 to 2020-06-30
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Symbol              5097 non-null   object
#  1   Series              5097 non-null   object
#  2   Prev Close          5097 non-null   float64
#  3   Open                5097 non-null   float64
#  4   High                5097 non-null   float64
#  5   Low                 5097 non-null   float64
#  6   Last                5097 non-null   float64
#  7   Close               5097 non-null   float64
#  8   VWAP                5097 non-null   float64
#  9   Volume              5097 non-null   int64
#  10  Turnover            5097 non-null   float64
#  11  Trades              2247 non-null   float64
#  12  Deliverable Volume  4588 non-null   float64
#  13  %Deliverble         4588 non-null   float64
# dtypes: float64(11), int64(1), object(2)
# ...

# %%
df.head()
# Out:
#                 Symbol Series  Prev Close   Open   High    Low   Last   Close  \
# Date
# 2000-01-03  ASIANPAINT     EQ      361.20  370.0  390.0  370.0  385.0  381.65
# 2000-01-04  ASIANPAINT     EQ      381.65  380.0  392.0  375.0  390.0  385.55
# 2000-01-05  ASIANPAINT     EQ      385.55  371.5  390.0  371.5  383.0  383.00
# 2000-01-06  ASIANPAINT     EQ      383.00  384.9  384.9  374.5  375.1  377.50
# 2000-01-07  ASIANPAINT     EQ      377.50  376.0  390.0  370.0  389.0  385.70
#
#               VWAP  Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2000-01-03  380.54    3318  1.262617e+11     NaN                 NaN
# 2000-01-04  383.50    4818  1.847699e+11     NaN                 NaN
# 2000-01-05  379.81    2628  9.981384e+10     NaN                 NaN
# 2000-01-06  379.88    3354  1.274114e+11     NaN                 NaN
# 2000-01-07  383.38    9589  3.676275e+11     NaN                 NaN
#
#             %Deliverble
# Date
# 2000-01-03          NaN
# ...

# %%
df['Open'].plot(figsize=(16,5),title="Opening stocks")
# Out:
# <AxesSubplot:title={'center':'Opening stocks'}, xlabel='Date'>
